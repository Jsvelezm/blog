# %% [markdown]
# # América Latina
# > A tutorial of fastpages for Jupyter notebooks.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter]
# - image: images/chart-preview.png

# %%
#hide

import numpy as np
import datetime
import pandas as pd
import altair as alt
from bs4 import BeautifulSoup
import re
from itertools import compress
import folium

# %%
# hide
datos_url = 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_19-covid-Confirmed.csv&filename=time_series_2019-ncov-Confirmed.csv'
datos = pd.read_csv(datos_url)
col = datos[datos['Country/Region'] == 'Colombia']
col =col.iloc[:,48:].T.reset_index()
col.columns = ['Index','Value']

# %%
# hide
datos_url = 'https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_19-covid-Confirmed.csv&filename=time_series_2019-ncov-Confirmed.csv'
datos = pd.read_csv(datos_url)
datos_mundiales  = datos.groupby(['Country/Region']).sum()

# %%
# hide
latinos =[ 'Argentina','Bolivia','Brazil','Chile','Colombia','Costa Rica','Cuba',
          'Ecuador','El Salvador','Granada','Guatemala','Guayana','Guayana Francesa',
          'Haiti','Honduras','Jamaica','Mexico','Nicaragua','Panama','Paraguay',
          'Peru','Puerto Rico','Dominica','Suriname','Uruguay'
          ,'Venezuela']
paises = datos['Country/Region']
datos_latinos = datos[[x in latinos for x in paises]]

# %%
# hide

'''
perdidos =  [i  not in paises.unique() for i in latinos ]
list(compress(latinos, perdidos))

'''
# Out:
# '\nperdidos =  [i  not in paises.unique() for i in latinos ]\nlist(compress(latinos, perdidos))\n\n'

# %%
# hide
date_time= datetime.datetime.now()
date_time = str(date_time)
"".join(date_time.split())
datos_mundiales.to_excel('covid-mundial'+ date_time +'.xlsx')

# %%
# hide

folium_map = folium.Map(location=[0, 0],
                        zoom_start = 2.5,
                        tiles="CartoDB dark_matter")

# %%
# hide
total = datos.iloc[:,4:].sum().sum()
for index, row in datos.iterrows():
    
    casos = (row['3/9/20'])
    radius = casos/total
    #if net_departures>0:
    color="#E37222" # tangerine
    #else:
    #color="#0A8A9F" # teal
    
    folium.CircleMarker(location=(row["Lat"],
                                  row["Long"]),
                        radius=radius,
                        color=color,
                        fill=True).add_to(folium_map)

# %%
folium_map.save("my_map.html")

# %%
from IPython.core.display import display, HTML
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
'''
import folium
from IPython.display import display
LDN_COORDINATES = (51.5074, 0.1278)
myMap = folium.Map(location=LDN_COORDINATES, zoom_start=12)
display(myMap)
'''
# Out:
# '\nimport folium\nfrom IPython.display import display\nLDN_COORDINATES = (51.5074, 0.1278)\nmyMap = folium.Map(location=LDN_COORDINATES, zoom_start=12)\ndisplay(myMap)\n'

# %%
folium_map2 = folium.Map(location=[ -1.8312, -78.1834],
                        zoom_start = 3,
                        tiles="CartoDB dark_matter")

# %%
total = datos_latinos.iloc[:,4:].sum().sum()
for index, row in datos_latinos.iterrows():
    
    casos = (row['3/9/20'])
    radius = casos/total
    #if net_departures>0:
    color="#E37222" # tangerine
    #else:
    #color="#0A8A9F" # teal
    
    folium.CircleMarker(location=(row["Lat"],
                                  row["Long"]),
                        radius=radius,
                        color=color,
                        fill=True).add_to(folium_map2)

# %%
folium_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
